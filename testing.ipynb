# %%
from testing import build_hyperparameter_net, test, save_results

# %%
optimizers = ["AS", "ACS", "MINMAX"]
alphas = [1.5, 1]
rhos = [0.95, 0.99]

# %%
beta = 1
n_ants = 20
v = 0.9
rho_loc = 0.99
max_iterations = 200
eval_info_interval = 50

# %%
hyperparameters_net = build_hyperparameter_net(optimizers, alphas, rhos, beta, n_ants, v, rho_loc, max_iterations, eval_info_interval)

# %%
problem_names = ["datasets/A/A-n33-k5", "datasets/B/B-n41-k6", "datasets/X/X-n172-k51"]

# %%
results = test(problem_names, hyperparameters_net, 10, save_path="results.json")
