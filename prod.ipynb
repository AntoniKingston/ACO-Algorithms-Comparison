# %%
# %matplotlib widget

# %%
from utils import CVRP
from visualize import visualize_cvrp_solution, visualize_pheromone_history

# %%
cvrp1 = CVRP("datasets/X/X-n420-k130")

# %%
opt_history = cvrp1.optimize(("ACS", 1, 1, 0.98, 100, 0.9, 0.99, 100, 10), True, True)
# Out:
# Iteration 1: Best Cost = inf
# Iteration 10: Best Cost = inf
# Iteration 20: Best Cost = inf
# Iteration 30: Best Cost = inf
# Iteration 40: Best Cost = inf
# Iteration 50: Best Cost = inf
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 opt_history = cvrp1.optimize(("ACS", 1, 1, 0.98, 100, 0.9, 0.99, 100, 10), True, True)
#
# File ~/studia/MSI/MSI2/proj1/utils.py:209, in CVRP.optimize(self, hyperparameters, eval_info, save_pheromone)
#     207 unvisited_nodes = unvisited_nodes[unvisited_nodes != current_node]
#     208 filtered_unvisited = unvisited_nodes[self.demands[unvisited_nodes] <= capacity_left]
# --> 209 depot_choice = np.array([self.depots[0]],
#     210                         dtype=int) if allow_unnecessary_depot_return else np.array([], dtype=int)
#     212 available_nodes = np.concatenate([depot_choice, filtered_unvisited])
# ...

# %%
visualize_cvrp_solution(cvrp1.coords, opt_history.best_solutions_history, depot_index=cvrp1.depots[0], minimal_cost=cvrp1.minimal_cost, optimal_solution=cvrp1.optimal_solution)
# Out:
# Pre-rendering 2 frames...
# Done.
# ...

# %%
visualize_pheromone_history(opt_history.pheromone_history)

# %%
opt_history.elapsed_time
# Out:
# 14.66118590799988

# %%
opt_history.pheromone_history
# Out:
# [array([[8.72296163e-04, 8.26303864e-01, 1.65494475e+00, ...,
#          8.72296163e-04, 1.56809478e+00, 8.72296163e-04],
#         [8.29513177e-01, 8.72296163e-04, 7.72837752e-01, ...,
#          8.72296163e-04, 8.81161271e-01, 8.72296163e-04],
#         [8.26303864e-01, 8.72296163e-04, 8.72296163e-04, ...,
#          8.72296163e-04, 8.72296163e-04, 8.72296163e-04],
#         ...,
#         [1.65494475e+00, 8.72296163e-04, 8.72296163e-04, ...,
#          8.72296163e-04, 8.72296163e-04, 8.72296163e-04],
#         [8.81161271e-01, 8.72296163e-04, 8.72296163e-04, ...,
#          8.72296163e-04, 8.72296163e-04, 8.72296163e-04],
#         [3.44553174e+00, 8.72296163e-04, 8.72296163e-04, ...,
#          7.96129322e-01, 8.72296163e-04, 8.72296163e-04]], shape=(32, 32)),
#  array([[8.54850240e-04, 1.87599798e+00, 2.68806604e+00, ...,
#          8.54850240e-04, 1.53673288e+00, 8.54850240e-04],
#         [8.12922914e-01, 8.54850240e-04, 7.57380997e-01, ...,
# ...

# %%
opt_history.best_solutions_history
# Out:
# [(np.float64(43683.5135595374),
#   [0,
#    np.int64(103),
#    np.int64(33),
#    np.int64(110),
#    np.int64(107),
#    np.int64(95),
#    np.int64(2),
#    np.int64(17),
#    np.int64(16),
#    np.int64(82),
#    np.int64(77),
#    np.int64(50),
#    np.int64(15),
#    np.int64(69),
#    np.int64(0),
#    np.int64(29),
#    np.int64(100),
#    np.int64(67),
#    np.int64(90),
#    np.int64(89),
#    np.int64(96),
#    np.int64(76),
#    np.int64(78),
#    np.int64(25),
#    np.int64(32),
#    np.int64(99),
#    np.int64(5),
#    np.int64(48),
#    np.int64(60),
#    np.int64(106),
#    np.int64(114),
#    np.int64(21),
#    np.int64(24),
#    np.int64(85),
#    np.int64(63),
#    np.int64(55),
#    np.int64(42),
#    np.int64(40),
#    np.int64(0),
#    np.int64(105),
#    np.int64(49),
#    np.int64(109),
#    np.int64(57),
#    np.int64(59),
#    np.int64(62),
#    np.int64(4),
#    np.int64(74),
#    np.int64(53),
#    np.int64(88),
#    np.int64(14),
#    np.int64(68),
# ...
